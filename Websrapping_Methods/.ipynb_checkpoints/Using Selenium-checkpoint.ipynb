# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
# Set up the WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# URL to scrape
url = 'https://www.w3schools.com/'
driver.get(url)

# Find all tutorial links
tutorials = driver.find_elements(By.CSS_SELECTOR, 'div.w3-bar-block a.w3-bar-item')
tutorial_data=[]
# Extract and print titles and URLs
for tutorial in tutorials:
    title = tutorial.text.strip()
    link = tutorial.get_attribute('href')
    print(f'Title: {title}\nURL: {link}\n')
    tutorial_data.append({'Title': title, 'URL': link})


# Close the browser
driver.quit()
# Out:
# Title:
# URL: https://www.w3schools.com/html/default.asp
#
# Title:
# URL: https://www.w3schools.com/css/default.asp
#
# Title:
# URL: https://www.w3schools.com/css/css_rwd_intro.asp
#
# Title:
# URL: https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#
# Title:
# URL: https://www.w3schools.com/w3css/default.asp
#
# Title:
# URL: https://www.w3schools.com/sass/default.php
#
# Title:
# URL: https://www.w3schools.com/colors/default.asp
#
# Title:
# URL: https://www.w3schools.com/icons/default.asp
#
# Title:
# URL: https://www.w3schools.com/graphics/svg_intro.asp
#
# Title:
# URL: https://www.w3schools.com/graphics/canvas_intro.asp
#
# Title:
# URL: https://www.w3schools.com/graphics/default.asp
#
# Title:
# URL: https://www.w3schools.com/charsets/default.asp
#
# Title:
# URL: https://www.w3schools.com/howto/default.asp
#
# Title:
# URL: https://www.w3schools.com/ai/default.asp
#
# Title:
# URL: https://www.w3schools.com/gen_ai/index.php
#
# Title:
# ...

# %%
df = pd.DataFrame(tutorial_data)
print(df.to_string())
# Out:
#     Title                                                                                                        URL
# 0                                                                         https://www.w3schools.com/html/default.asp
# 1                                                                          https://www.w3schools.com/css/default.asp
# 2                                                                    https://www.w3schools.com/css/css_rwd_intro.asp
# 3                                                              https://www.w3schools.com/bootstrap/bootstrap_ver.asp
# 4                                                                        https://www.w3schools.com/w3css/default.asp
# 5                                                                         https://www.w3schools.com/sass/default.php
# 6                                                                       https://www.w3schools.com/colors/default.asp
# ...
